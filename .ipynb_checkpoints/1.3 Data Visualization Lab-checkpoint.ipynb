# %% [markdown]
# # Lab Instructions
#
# You have been hired by a record executive to design a guaranteed smash hit song based on data.  The exec has decided that if you make a song that has all the most popular features of recent songs then it will definitely be a hit.  So if - for example - the most common key in the Spotify data is C# then we would want the song we are designing to also be in C#.  If a "typical" value of BPM is between 120 and 130 then we would want the song we are designing to also have a tempo between 120 and 130 BMP.
#
# Visualize and describe the distribution of:
# * BPM
# * Key
# * Mode
# * Danceability
# * Energy
# * Speechiness
# * Acousticness
#
# Based on your visualizations and calculations, what values for each of these features would make a song a guaranteed smash hit?  For quantitative features, you should propose a range of values.
#
# Use a large language model to help you write code to identify if there are any songs in the Spotify dataset that meet all of the criteria we determined.  What is/are the artist(s) and title(s) of the song?  Were any of these songs actually popular?
#
# Pick a song that you know was a smash hit. How do the values of BPM, key, mode, danceability, etc. compare to other songs?
#
# **Hint:**  Import the Spotify data using `df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')`.

# %%
import pandas as pd

df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %% [markdown]
# ## Beats per Minute

# %%
#Note that a box plot would also be appropriate here although students are typically not familiar with that kind
#of visualization yet

df['bpm'].plot(kind='hist',
               title='Distribution of Beats Per Minute in Songs on Spotify',
               xlabel='Beats per Minute')
# Out:
# <Axes: title={'center': 'Distribution of Beats Per Minute in Songs on Spotify'}, xlabel='Beats per Minute', ylabel='Frequency'>

# %%
df['bpm'].describe()
# Out:
# count    953.000000
# mean     122.540399
# std       28.057802
# min       65.000000
# 25%      100.000000
# 50%      121.000000
# 75%      140.000000
# max      206.000000
# Name: bpm, dtype: float64

# %% [markdown]
# The mean and median tempo of songs in the Spotify dataset is about 120 bpm with a range of 65 to 206 bpm.  Most songs have a tempo between about 100 and 140 bpm.

# %% [markdown]
# ## Key

# %%
#Note a pie chart would also be acceptable here

df['key'].value_counts().plot(kind='bar',
                              title='Distribution of Key in Songs on Spotify')
# Out:
# <Axes: title={'center': 'Distribution of Key in Songs on Spotify'}, xlabel='key'>

# %%
df['key'].value_counts()
# Out:
# key
# C#    120
# G      96
# G#     91
# F      89
# B      81
# D      81
# A      75
# F#     73
# E      62
# A#     57
# D#     33
# Name: count, dtype: int64

# %% [markdown]
# The most common key in the Spotify dataset is C#.

# %% [markdown]
# ## Mode

# %%
#Note that a bar chart would also be appropriate

df['mode'].value_counts().plot(kind='pie',
                               title='Distribution of Mode in Spotify Songs')
# Out:
# <Axes: title={'center': 'Distribution of Mode in Spotify Songs'}, ylabel='count'>

# %%
df['mode'].value_counts()
# Out:
# mode
# Major    550
# Minor    403
# Name: count, dtype: int64

# %% [markdown]
# Songs in the Spotify dataset are more commonly composed in a major mode.

# %% [markdown]
# ## Danceability

# %%
#Note that a box plot would also be appropriate here although students are typically not familiar with that kind
#of visualization yet

df['danceability_%'].plot(kind='hist',
                           title='Distribution of Dancability in Songs on Spotify',
                           xlabel='Percent')
# Out:
# <Axes: title={'center': 'Distribution of Dancability in Songs on Spotify'}, xlabel='Percent', ylabel='Frequency'>

# %%
df['danceability_%'].describe()
# Out:
# count    953.00000
# mean      66.96957
# std       14.63061
# min       23.00000
# 25%       57.00000
# 50%       69.00000
# 75%       78.00000
# max       96.00000
# Name: danceability_%, dtype: float64

# %% [markdown]
# Songs in the Spotify dataset tend to be very dancable. The range is from 23% to 96% but the most songs have a dancibility of about 60% to 80%.

# %% [markdown]
# ## Energy

# %%
#Note that a box plot would also be appropriate here although students are typically not familiar with that kind
#of visualization yet

df['energy_%'].plot(kind='hist',
                    title='Distribution of Energy in Songs on Spotify',
                    xlabel='Percent')
# Out:
# <Axes: title={'center': 'Distribution of Energy in Songs on Spotify'}, xlabel='Percent', ylabel='Frequency'>

# %%
df['energy_%'].describe()
# Out:
# count    953.000000
# mean      64.279119
# std       16.550526
# min        9.000000
# 25%       53.000000
# 50%       66.000000
# 75%       77.000000
# max       97.000000
# Name: energy_%, dtype: float64

# %% [markdown]
# Songs in the Spotify dataset tend to be high energy. The range is from 9% to 97% but the most songs have a dancibility of about 55% to 80%.

# %% [markdown]
# ## Speechiness

# %%
#Note that a box plot would also be appropriate here although students are typically not familiar with that kind
#of visualization yet

df['speechiness_%'].plot(kind='hist',
                    title='Distribution of Speechiness in Songs on Spotify',
                    xlabel='Percent')
# Out:
# <Axes: title={'center': 'Distribution of Speechiness in Songs on Spotify'}, xlabel='Percent', ylabel='Frequency'>

# %%
df['speechiness_%'].describe()
# Out:
# count    953.000000
# mean      10.131165
# std        9.912888
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%       11.000000
# max       64.000000
# Name: speechiness_%, dtype: float64

# %% [markdown]
# Songs in the Spotify dataset tend to be very low speechiness. The range is from 2% to 64% but the most songs have a speechiness of less than 10%.

# %% [markdown]
# ## Acousticness

# %%
#Note that a box plot would also be appropriate here although students are typically not familiar with that kind
#of visualization yet

df['acousticness_%'].plot(kind='hist',
                    title='Distribution of Acousticness in Songs on Spotify',
                    xlabel='Percent')
# Out:
# <Axes: title={'center': 'Distribution of Acousticness in Songs on Spotify'}, xlabel='Percent', ylabel='Frequency'>

# %%
df['acousticness_%'].describe()
# Out:
# count    953.000000
# mean      27.057712
# std       25.996077
# min        0.000000
# 25%        6.000000
# 50%       18.000000
# 75%       43.000000
# max       97.000000
# Name: acousticness_%, dtype: float64

# %% [markdown]
# Songs in the Spotify dataset are a mix of acousitic and not. A bunch of songs have a really low percent acousticness (<10%), but otherwise the distribution is prettty spread out up to 97% acousticness.

# %% [markdown]
# ## Creating the engineered song

# %%
#These ranges don't have to match prefectly but they should approximately capture the most common values of each attribute in the dataset

filtered_df = df.loc[(df['bpm'] >= 100) & (df['bpm'] <= 140) &
                     (df['key'] == 'A') &
                     (df['mode'] == 'Minor')  &
                     (df['danceability_%'] > 60) & (df['danceability_%'] < 80) &
                     (df['energy_%'] > 60) & (df['energy_%'] < 80) &
                     (df['speechiness_%'] < 10) &
                     (df['acousticness_%'] < 10)]

filtered_df.head()
# Out:
#               track_name artist(s)_name  artist_count  released_year  \
# 159  Under The Influence    Chris Brown             1           2019
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 159              10             4                  3859                 26
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 159  929964809                 133  ...  117   A  Minor             73
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 159         31       69              6                   0          11
#
#      speechiness_%
# 159              4
#
# [1 rows x 24 columns]

# %% [markdown]
# Yes, trying to engineer a song like this could work.  Under The Influence meets all the requirements for our engineered "best" song, and, according to Wikipedia:
#
# "Under the Influence" received great success internationally, reaching the top ten in more than twenty countries between 2022 and 2023, including United Kingdom, Australia, India, New Zealand and South Africa, while peaking at number 12 on the US Billboard Hot 100.

# %% [markdown]
# ## Comparing a popular song to the engineered song characteristics

# %% [markdown]
# A song that I recognize as being a big hit is Cruel Summer by Taylor Swift.  (Note: I accept whatever song students choose as being a big hit).

# %%
cruel_summer = df.loc[df['track_name'] == 'Cruel Summer']

cruel_summer[['track_name', 'artist(s)_name', 'bpm', 'key', 'mode', 'danceability_%', 'energy_%', 'acousticness_%', 'speechiness_%']]
# Out:
#      track_name artist(s)_name  bpm key   mode  danceability_%  energy_%  \
# 3  Cruel Summer   Taylor Swift  170   A  Major              55        72
#
#    acousticness_%  speechiness_%
# 3              11             15

# %% [markdown]
# Compared to our engineered song characteristics, Cruel summer is a little faster, is in A rather than C#, is slightly less danceable, and has slightly more acousticness and speechiness.
